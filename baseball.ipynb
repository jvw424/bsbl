# %%
import pandas as pd
import numpy as np

# %%
hilt = pd.read_csv('Jake_Hilton.csv')
hilt
# Out:
#      PitchNo        Date         Time  PAofInning  PitchofPA  \
# 0          1  2023-02-03  14:02:50.07           1          1
# 1          2  2023-02-03  14:03:05.53           1          2
# 2          3  2023-02-03  14:03:24.51           1          3
# 3          4  2023-02-03  14:03:50.06           2          1
# 4          5  2023-02-03  14:04:04.86           2          2
# ..       ...         ...          ...         ...        ...
# 263      264  2023-02-03  16:32:07.47           3          1
# 264      265  2023-02-03  16:32:26.17           3          2
# 265      266  2023-02-03  16:33:44.92           3          3
# 266      267  2023-02-03  16:34:07.13           3          4
# 267      268  2023-02-03  16:34:36.01           3          5
#
#               Pitcher   PitcherId PitcherThrows PitcherTeam           Batter  \
# 0        Hilton, Jake  1000115590          Left     POM_COL   Doughty, Jacob
# ...

# %%
h = hilt.loc[hilt['Pitcher'] == 'Hilton, Jake']
h
# Out:
#      PitchNo        Date         Time  PAofInning  PitchofPA       Pitcher  \
# 0          1  2023-02-03  14:02:50.07           1          1  Hilton, Jake
# 1          2  2023-02-03  14:03:05.53           1          2  Hilton, Jake
# 2          3  2023-02-03  14:03:24.51           1          3  Hilton, Jake
# 3          4  2023-02-03  14:03:50.06           2          1  Hilton, Jake
# 4          5  2023-02-03  14:04:04.86           2          2  Hilton, Jake
# ..       ...         ...          ...         ...        ...           ...
# 137      138  2023-02-03  15:16:44.33           1          2  Hilton, Jake
# 138      139  2023-02-03  15:16:59.51           1          3  Hilton, Jake
# 139      140  2023-02-03  15:17:22.27           2          1  Hilton, Jake
# 140      141  2023-02-03  15:17:34.24           2          2  Hilton, Jake
# 141      142  2023-02-03  15:18:09.29           3          1  Hilton, Jake
#
#       PitcherId PitcherThrows PitcherTeam           Batter  ...  \
# ...

# %%
filter = h[['Date', 'Pitcher', 'RelSpeed', 'SpinRate','Tilt',  'InducedVertBreak','HorzBreak', 'VertBreak', 'RelHeight', 'RelSide', 'VertApprAngle', 'HorzApprAngle', 'Inning', 'ZoneSpeed','ZoneTime', 'EffectiveVelo',  'SpeedDrop', 'Extension','PitcherThrows', 'Batter', 'TaggedPitchType', 'AutoPitchType', 'PitchCall', 'KorBB', 'TaggedHitType', 'PlayResult', 'VertRelAngle',  'HorzRelAngle',  'PlateLocHeight', 'PlateLocSide', 'HitSpinAxis', 'HangTime', 'Bearing', 'Distance', 'HitSpinRate','Direction', 'Angle', 'ExitSpeed',]]

# %%
filter
# Out:
#            Date       Pitcher  RelSpeed     SpinRate    SpinAxis  \
# 0    2023-02-03  Hilton, Jake  88.73569  2190.979131  150.145950
# 1    2023-02-03  Hilton, Jake  89.08526  2409.825446  170.144190
# 2    2023-02-03  Hilton, Jake  89.38612  2446.598691  160.543731
# 3    2023-02-03  Hilton, Jake  89.18275  2360.805178  162.870253
# 4    2023-02-03  Hilton, Jake  89.02457  2436.409081  159.688944
# ..          ...           ...       ...          ...         ...
# 137  2023-02-03  Hilton, Jake  85.65249  2277.997655  143.021915
# 138  2023-02-03  Hilton, Jake  84.85136  2229.188944  163.436180
# 139  2023-02-03  Hilton, Jake  70.32494  2295.073777  320.943185
# 140  2023-02-03  Hilton, Jake  84.39266  2189.103066  159.111237
# 141  2023-02-03  Hilton, Jake  84.64261  2217.865173  144.679765
#
#      InducedVertBreak  HorzBreak  VertBreak  RelHeight  RelSide  ...  \
# 0            18.20155   -9.76162  -17.55847    5.25165 -1.09559  ...
# ...
